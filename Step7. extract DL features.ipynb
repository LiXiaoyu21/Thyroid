# %% [markdown]
# ## 深度学习特征
#
# 提取CT、MRI、内镜、Xray等影像数据的深度学习特征。
#
# ### Onekey步骤
#
# 1. 将待提取的数据转化成jpg，可以参考使用OKT-convert2jpg或者OKT-crop_max_roi两个Onekey工具。
# 2. 获取到指定目录的所有图像数据。
# 3. 选择要提取什么样的模型的深度学习特征，目前Onekey支持主流的深度学习模型。（可以考虑使用Onekey进行迁移学习）
# 4. 提取特征，保存特征文件。

# %%
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取')
# Out:
# [2025-12-03 16:34:18 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！

# %% [markdown]
# ## 获取待提取特征的文件
#
# 提供两种批量处理的模式：
# 1. 目录模式，提取指定目录下的所有jpg文件的特征。
# 2. 文件模式，待提取的数据存储在文件中，每行一个样本。
#
# 当然也可以在最后自己指定手动提取指定若干文件。

# %%
#### 获取数据
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取|获取数据')
# Out:
# [2025-12-03 16:34:18 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import monai
from glob import glob
import matplotlib.pyplot as plt
from onekey_algo import get_param_in_cwd

os.makedirs('features', exist_ok=True)
mydir = get_param_in_cwd('data_pattern')
samples = [os.path.join(mydir, f) for f in os.listdir(mydir) if f.endswith('.jpg') or f.endswith('.png')]
samples
# Out:
# ['D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\100.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1001.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1003.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\101.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1015.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1024.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1026.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1029.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\103.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1030.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1031.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1033.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1036.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1037.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\104.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1044.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1048.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1051.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1052.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1058.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1059.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\106.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1061.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1063.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1065.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\107.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1070.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1072.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1079.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\108.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1081.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1083.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1084.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1085.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1087.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1088.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1089.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1091.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1092.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1094.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1095.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1098.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\11.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\110.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1101.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1102.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1106.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\111.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1110.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1112.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1114.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1116.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1117.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1119.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\112.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1120.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1121.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1124.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1126.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\113.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\114.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\115.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\116.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\117.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\118.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\119.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\12.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\120.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1200.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1201.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1204.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1206.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1208.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\121.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1210.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1212.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1213.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1217.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1218.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1219.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1221.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1222.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1223.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1224.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1225.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1226.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1227.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\123.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1230.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1231.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1232.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1233.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1234.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1235.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1236.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1238.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1239.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\124.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1240.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1242.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1243.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1244.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1245.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1246.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1247.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\125.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1252.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1255.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1256.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1257.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\126.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1260.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1261.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1262.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1263.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\127.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\128.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\129.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\13.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1301.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1302.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1303.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1305.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1306.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1307.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1308.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1309.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\131.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1310.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1311.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1312.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1313.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1314.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1315.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1316.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1317.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1318.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1319.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1320.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1321.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1322.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1323.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1324.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1325.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1326.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1327.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1328.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1329.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\133.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1330.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1332.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1333.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1334.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1336.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1337.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1339.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\134.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1340.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1341.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1342.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1344.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1345.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1346.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1347.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1348.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1349.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\135.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1350.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1351.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1352.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1353.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1356.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1357.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1358.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\136.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1360.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1361.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1362.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1363.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1364.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1366.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1367.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1368.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1369.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\137.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1370.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1371.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1372.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1373.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1374.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1375.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1376.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1377.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1378.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1379.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1380.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1381.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1382.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1384.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1386.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1387.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1389.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\139.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1390.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1391.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1392.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1393.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1394.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1395.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1396.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1397.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1398.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\14.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\140.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1400.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1401.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1402.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1404.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1405.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1408.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1409.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\141.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1410.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1411.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1412.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1413.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1414.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\1415.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\143.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\145.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\147.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\148.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\149.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\150.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\151.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\152.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\153.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\154.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\155.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\156.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\157.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\158.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\159.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\160.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\162.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\163.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\164.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\165.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\166.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\167.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\168.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\169.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\17.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\172.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\173.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\175.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\179.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\18.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\181.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\182.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\183.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\184.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\185.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\186.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\187.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\188.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\189.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\19.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\190.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\192.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\195.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\198.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\199.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\2.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\200.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\201.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\202.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\203.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\206.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\207.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\208.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\209.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\211.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\212.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\213.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\214.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\215.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\216.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\217.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\218.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\22.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\220.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\221.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\222.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\223.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\224.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\226.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\227.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\228.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\229.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\23.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\230.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\231.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\233.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\234.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\235.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\236.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\237.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\238.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\239.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\24.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\241.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\242.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\243.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\245.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\246.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\247.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\248.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\249.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\25.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\251.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\252.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\254.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\255.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\256.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\257.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\259.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\260.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\261.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\262.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\264.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\266.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\267.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\268.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\269.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\27.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\270.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\271.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\272.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\273.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\274.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\275.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\276.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\277.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\278.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\279.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\281.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\282.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\283.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\284.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\285.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\286.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\287.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\288.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\289.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\29.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\290.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\291.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\292.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\293.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\294.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\296.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\298.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\299.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\3.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\30.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\301.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\302.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\303.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\304.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\305.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\306.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\307.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\308.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\310.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\311.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\313.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\314.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\316.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\318.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\319.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\32.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\321.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\323.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\324.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\325.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\326.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\327.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\328.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\329.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\33.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\330.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\331.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\336.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\337.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\338.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\339.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\34.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\340.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\342.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\343.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\345.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\346.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\347.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\348.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\349.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\35.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\352.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\353.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\356.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\357.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\358.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\359.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\360.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\366.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\37.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\371.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\373.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\378.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\38.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\382.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\385.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\392.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\4.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\40.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\404.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\406.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\409.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\411.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\413.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\415.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\418.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\426.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\428.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\43.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\439.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\44.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\443.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\445.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\446.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\45.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\450.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\453.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\455.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\456.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\461.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\462.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\468.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\47.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\470.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\472.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\473.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\475.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\480.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\481.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\482.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\483.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\485.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\486.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\487.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\489.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\490.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\497.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\5.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\50.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\501.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\502.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\504.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\505.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\509.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\51.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\511.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\512.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\513.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\516.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\52.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\520.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\523.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\524.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\525.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\526.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\528.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\53.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\531.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\533.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\535.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\536.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\537.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\538.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\539.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\540.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\541.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\544.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\548.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\55.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\550.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\551.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\552.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\554.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\555.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\557.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\558.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\56.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\563.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\565.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\568.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\569.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\573.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\578.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\579.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\58.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\583.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\584.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\585.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\586.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\59.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\591.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\592.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\597.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\598.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\599.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\6.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\601.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\603.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\605.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\606.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\61.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\611.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\612.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\613.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\616.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\618.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\619.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\62.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\620.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\621.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\622.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\623.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\624.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\625.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\629.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\63.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\630.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\631.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\632.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\635.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\637.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\638.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\64.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\640.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\643.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\644.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\645.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\646.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\647.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\648.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\65.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\657.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\658.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\660.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\662.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\669.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\67.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\670.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\672.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\673.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\674.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\675.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\679.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\68.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\680.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\683.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\687.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\689.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\69.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\693.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\694.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\696.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\697.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\699.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\7.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\700.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\703.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\706.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\707.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\708.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\709.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\71.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\710.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\711.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\712.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\722.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\723.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\725.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\726.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\728.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\73.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\730.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\731.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\732.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\733.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\735.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\737.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\739.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\74.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\740.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\741.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\742.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\744.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\747.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\75.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\751.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\752.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\753.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\759.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\76.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\763.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\765.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\766.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\767.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\769.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\77.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\771.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\773.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\774.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\777.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\778.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\779.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\78.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\780.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\781.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\782.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\785.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\787.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\788.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\79.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\792.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\793.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\794.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\795.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\797.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\798.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\799.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\8.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\801.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\802.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\805.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\806.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\808.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\81.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\810.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\811.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\812.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\813.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\815.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\816.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\818.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\821.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\823.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\824.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\825.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\827.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\83.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\831.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\832.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\833.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\835.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\837.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\838.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\840.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\841.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\842.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\843.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\844.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\845.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\847.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\848.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\849.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\85.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\850.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\851.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\852.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\853.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\854.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\856.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\858.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\859.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\86.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\860.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\861.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\862.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\863.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\864.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\865.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\866.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\868.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\87.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\871.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\873.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\875.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\879.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\88.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\880.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\885.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\887.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\888.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\889.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\89.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\890.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\894.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\895.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\896.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\897.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\898.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\899.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\90.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\902.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\903.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\906.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\907.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\909.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\91.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\912.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\914.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\915.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\917.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\919.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\921.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\922.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\923.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\926.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\929.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\93.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\930.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\931.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\934.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\935.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\941.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\944.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\945.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\949.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\950.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\952.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\954.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\957.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\963.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\964.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\965.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\966.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\969.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\97.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\972.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\973.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\977.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\978.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\980.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\981.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\984.nii.png',
#  'D:\\\\task1DL\\\\11.3\\\\调参761\\\\ROIonly\\99.nii.png']

# %% [markdown]
# ## 确定提取特征
#
# 通过关键词获取要提取那一层的特征。
#
# ### 支持的模型名称
#
# 模型名称替换代码中的 `model_name`变量的值。
#
# | **模型系列** | **模型名称**                                                 |
# | ------------ | ------------------------------------------------------------ |
# | AlexNet      | alexnet                                                      |
# | VGG          | vgg11, vgg11_bn, vgg13, vgg13_bn, vgg16, vgg16_bn, vgg19_bn, vgg19 |
# | ResNet       | resnet18, resnet34, resnet50, resnet101, resnet152, resnext50_32x4d, resnext101_32x8d, wide_resnet50_2, wide_resnet101_2 |
# | DenseNet     | densenet121, densenet169, densenet201, densenet161           |
# | Inception    | googlenet, inception_v3                                      |
# | SqueezeNet   | squeezenet1_0, squeezenet1_1                                 |
# | ShuffleNetV2 | shufflenet_v2_x2_0, shufflenet_v2_x0_5, shufflenet_v2_x1_0, shufflenet_v2_x1_5 |
# | MobileNet    | mobilenet_v2, mobilenet_v3_large, mobilenet_v3_small         |
# | MNASNet      | mnasnet0_5, mnasnet0_75, mnasnet1_0, mnasnet1_3              |

# %%
#### 获取数据
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取|确定模型和特征')
# Out:
# [2025-12-03 16:34:18 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！

# %%
from onekey_algo.custom.components.comp2 import extract, print_feature_hook, reg_hook_on_module, \
    init_from_model, init_from_onekey

model_name = get_param_in_cwd('model_name')
model, transformer, device = init_from_onekey(os.path.join(get_param_in_cwd('model_root'), model_name, 'viz'))
for n, m in model.named_modules():
    print('Feature name:', n, "|| Module:", m)
# Out:
# [2025-12-03 16:34:19 - <frozen onekey_algo.custom.components.comp2>: 235]	INFO	模型参数：{'pretrained': False, 'model_name': 'resnet50', 'num_classes': 2, 'in_channels': 3}
# Feature name:  || Module: ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )
# Feature name: conv1 || Module: Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# Feature name: bn1 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: relu || Module: ReLU(inplace=True)
# Feature name: maxpool || Module: MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Feature name: layer1 || Module: Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# )
# Feature name: layer1.0 || Module: Bottleneck(
#   (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (downsample): Sequential(
#     (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer1.0.conv1 || Module: Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.0.bn1 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.0.conv2 || Module: Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer1.0.bn2 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.0.conv3 || Module: Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.0.bn3 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.0.relu || Module: ReLU(inplace=True)
# Feature name: layer1.0.downsample || Module: Sequential(
#   (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer1.0.downsample.0 || Module: Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.0.downsample.1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1 || Module: Bottleneck(
#   (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer1.1.conv1 || Module: Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.1.bn1 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1.conv2 || Module: Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer1.1.bn2 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1.conv3 || Module: Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.1.bn3 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1.relu || Module: ReLU(inplace=True)
# Feature name: layer1.2 || Module: Bottleneck(
#   (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer1.2.conv1 || Module: Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.2.bn1 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.2.conv2 || Module: Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer1.2.bn2 || Module: BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.2.conv3 || Module: Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer1.2.bn3 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.2.relu || Module: ReLU(inplace=True)
# Feature name: layer2 || Module: Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (3): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# )
# Feature name: layer2.0 || Module: Bottleneck(
#   (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (downsample): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer2.0.conv1 || Module: Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.0.bn1 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.0.conv2 || Module: Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Feature name: layer2.0.bn2 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.0.conv3 || Module: Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.0.bn3 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.0.relu || Module: ReLU(inplace=True)
# Feature name: layer2.0.downsample || Module: Sequential(
#   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer2.0.downsample.0 || Module: Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
# Feature name: layer2.0.downsample.1 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1 || Module: Bottleneck(
#   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer2.1.conv1 || Module: Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.1.bn1 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1.conv2 || Module: Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer2.1.bn2 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1.conv3 || Module: Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.1.bn3 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1.relu || Module: ReLU(inplace=True)
# Feature name: layer2.2 || Module: Bottleneck(
#   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer2.2.conv1 || Module: Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.2.bn1 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.2.conv2 || Module: Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer2.2.bn2 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.2.conv3 || Module: Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.2.bn3 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.2.relu || Module: ReLU(inplace=True)
# Feature name: layer2.3 || Module: Bottleneck(
#   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer2.3.conv1 || Module: Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.3.bn1 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.3.conv2 || Module: Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer2.3.bn2 || Module: BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.3.conv3 || Module: Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer2.3.bn3 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.3.relu || Module: ReLU(inplace=True)
# Feature name: layer3 || Module: Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (3): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (4): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (5): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# )
# Feature name: layer3.0 || Module: Bottleneck(
#   (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (downsample): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer3.0.conv1 || Module: Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.0.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.0.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Feature name: layer3.0.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.0.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.0.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.0.relu || Module: ReLU(inplace=True)
# Feature name: layer3.0.downsample || Module: Sequential(
#   (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.0.downsample.0 || Module: Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
# Feature name: layer3.0.downsample.1 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer3.1.conv1 || Module: Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.1.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer3.1.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.1.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1.relu || Module: ReLU(inplace=True)
# Feature name: layer3.2 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer3.2.conv1 || Module: Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.2.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.2.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer3.2.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.2.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.2.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.2.relu || Module: ReLU(inplace=True)
# Feature name: layer3.3 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer3.3.conv1 || Module: Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.3.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.3.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer3.3.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.3.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.3.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.3.relu || Module: ReLU(inplace=True)
# Feature name: layer3.4 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer3.4.conv1 || Module: Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.4.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.4.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer3.4.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.4.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.4.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.4.relu || Module: ReLU(inplace=True)
# Feature name: layer3.5 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer3.5.conv1 || Module: Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.5.bn1 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.5.conv2 || Module: Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer3.5.bn2 || Module: BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.5.conv3 || Module: Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer3.5.bn3 || Module: BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.5.relu || Module: ReLU(inplace=True)
# Feature name: layer4 || Module: Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# )
# Feature name: layer4.0 || Module: Bottleneck(
#   (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (downsample): Sequential(
#     (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer4.0.conv1 || Module: Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.0.bn1 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.0.conv2 || Module: Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Feature name: layer4.0.bn2 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.0.conv3 || Module: Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.0.bn3 || Module: BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.0.relu || Module: ReLU(inplace=True)
# Feature name: layer4.0.downsample || Module: Sequential(
#   (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer4.0.downsample.0 || Module: Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
# Feature name: layer4.0.downsample.1 || Module: BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1 || Module: Bottleneck(
#   (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer4.1.conv1 || Module: Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.1.bn1 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1.conv2 || Module: Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer4.1.bn2 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1.conv3 || Module: Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.1.bn3 || Module: BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1.relu || Module: ReLU(inplace=True)
# Feature name: layer4.2 || Module: Bottleneck(
#   (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )
# Feature name: layer4.2.conv1 || Module: Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.2.bn1 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.2.conv2 || Module: Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: layer4.2.bn2 || Module: BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.2.conv3 || Module: Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: layer4.2.bn3 || Module: BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.2.relu || Module: ReLU(inplace=True)
# Feature name: avgpool || Module: AdaptiveAvgPool2d(output_size=(1, 1))
# Feature name: fc || Module: Linear(in_features=2048, out_features=2, bias=True)

# %% [markdown]
# ## 提取特征
#
# `Feature name:` 之后的名称为要提取的特征名，例如`layer3.0.conv2`, 一般深度学习特征提取最后一层，例如`avgpool`

# %%
#### 提取特征
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取|提取特征')
# Out:
# [2025-12-03 16:34:21 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！

# %%
from functools import partial
feature_name = 'avgpool'
with open(f'features/{model_name}_features.csv', 'w') as outfile:
    hook = partial(print_feature_hook, fp=outfile)
    find_num = reg_hook_on_module(feature_name, model, hook)
    results = extract(samples, model, transformer, device, fp=outfile)

# %% [markdown]
# ## 读取数据

# %%
#### 特征读取
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取|特征读取')
# Out:
# [2025-12-03 16:35:09 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！

# %%
import pandas as pd
features = pd.read_csv(f'features/{model_name}_features.csv', header=None)
features.columns=['ID'] + [f"DL_{i}" for i in range(features.shape[1] - 1)]
features.to_csv(f'features/{model_name}_features.csv', index=False)
features
# Out:
#                ID   DL_0   DL_1   DL_2   DL_3   DL_4   DL_5   DL_6   DL_7  \
# 0       1.nii.png  0.276  1.144  0.177  0.843  0.412  0.439  1.324  0.874
# 1     100.nii.png  0.264  0.366  0.353  0.965  0.354  0.107  2.350  0.466
# 2    1001.nii.png  0.506  0.621  0.518  1.303  0.355  0.814  1.089  1.240
# 3    1003.nii.png  0.396  0.370  0.274  0.216  1.067  0.277  0.757  1.178
# 4     101.nii.png  0.605  0.982  0.851  0.929  1.112  0.220  2.031  0.607
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 755   978.nii.png  0.382  1.180  0.947  0.732  1.602  2.115  0.299  1.516
# 756   980.nii.png  0.169  0.322  1.623  0.297  1.701  0.505  1.056  0.522
# 757   981.nii.png  0.122  0.840  1.109  0.390  1.003  0.854  1.330  0.806
# 758   984.nii.png  0.037  0.332  0.440  0.826  1.736  0.580  1.338  0.017
# 759    99.nii.png  0.277  0.997  0.805  0.532  0.740  1.223  1.583  1.096
#
#       DL_8  ...  DL_2038  DL_2039  DL_2040  DL_2041  DL_2042  DL_2043  \
# 0    0.349  ...    1.210    0.069    0.251    0.845    0.589    0.061
# 1    0.921  ...    0.438    0.626    1.982    0.697    1.078    0.103
# 2    0.330  ...    0.572    0.355    0.681    0.313    0.608    0.052
# 3    0.258  ...    0.440    0.448    0.110    0.735    0.584    0.078
# 4    0.087  ...    0.109    0.154    0.113    0.893    0.489    0.305
# ..     ...  ...      ...      ...      ...      ...      ...      ...
# 755  0.265  ...    0.219    0.175    0.389    0.565    0.345    0.117
# 756  0.349  ...    0.157    0.287    1.195    0.692    0.931    0.126
# 757  0.156  ...    0.147    0.659    0.454    0.865    1.995    0.139
# 758  0.684  ...    0.280    0.755    0.497    0.257    1.900    0.051
# 759  0.179  ...    0.555    0.265    1.751    0.470    0.515    0.236
#
#      DL_2044  DL_2045  DL_2046  DL_2047
# 0      1.077    0.563    0.980    0.773
# 1      0.891    0.264    1.007    0.483
# 2      1.047    0.414    0.732    0.592
# 3      0.428    0.397    1.430    0.084
# 4      0.637    0.198    0.376    0.481
# ..       ...      ...      ...      ...
# 755    0.606    0.265    0.388    0.054
# 756    0.377    0.917    1.500    0.095
# 757    1.335    0.283    1.388    0.039
# 758    0.450    0.102    0.515    0.403
# 759    1.383    0.568    0.722    0.277
#
# [760 rows x 2049 columns]

# %% [markdown]
# ### 深度特征压缩
#
# 深度学习特征压缩，注意压缩到的维度需要小于样本数
#
# ```python
# def compress_df_feature(features: pd.DataFrame, dim: int, not_compress: Union[str, List[str]] = None,
#                         prefix='') -> pd.DataFrame:
#     """
#     压缩深度学习特征
#     Args:
#         features: 特征DataFrame
#         dim: 需要压缩到的维度，此值需要小于样本数
#         not_compress: 不进行压缩的列。
#         prefix: 所有特征的前缀。
#
#     Returns:
#
#     """
# ```

# %%
from onekey_algo.custom.components.comp1 import compress_df_feature

cm_features = compress_df_feature(features=features, dim=8, prefix='DL_', not_compress='ID')
cm_features.to_csv(f'features/{model_name}_compress_features.csv', header=True, index=False)

# %% [markdown]
# ### 迁移学习
#
# 使用Onekey，提取基于迁移学习的模型特征。

# %%
#### 特征读取
from onekey_algo.custom.Manager import onekey_show
onekey_show('深度学习特征提取|Onekey迁移学习')
# Out:
# [2025-12-03 16:35:10 - <frozen onekey_algo.custom.Manager>: 159]	INFO	播放视频功能已经设置成：Disable！
